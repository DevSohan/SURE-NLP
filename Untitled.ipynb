# %%
import os
files_path = os.listdir('Text')
print(files_path)
# Out:
# ['Build4People.txt', 'Charms.txt', 'emplement!.txt', 'FloodAdaptVN.txt', 'GreenCityLabHue.txt', 'IMECOGIP.txt', 'LIRLAP.txt', 'MYrisk.txt', 'Polyurbanwaters.txt', 'URA.txt']

# %%
# !pip install PyPDF2

# %%
import sys

print (sys.stdout.encoding)
print ("Stöcker".encode(sys.stdout.encoding, errors='replace'))
print ("Стоескер".encode(sys.stdout.encoding, errors='replace'))
# Out:
# UTF-8
# b'St\xc3\xb6cker'
# b'\xd0\xa1\xd1\x82\xd0\xbe\xd0\xb5\xd1\x81\xd0\xba\xd0\xb5\xd1\x80'

# %%
# !pip install wordcloud
# !pip install matplotlib

# %%
import collections
import numpy as np
import pandas as pd
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib import rcParams
from wordcloud import WordCloud, STOPWORDS
all_headlines = """
When it comes to evaluating the performance of keyword extractors, you can use some of the standard metrics in machine learning: accuracy, precision, recall, and F1 score. However, these metrics don’t reflect partial matches; they only consider the perfect match between an extracted segment and the correct prediction for that tag.
Fortunately, there are some other metrics capable of capturing partial matches. An example of this is ROUGE.
"""
stopwords = STOPWORDS
wordcloud = WordCloud(stopwords=stopwords, background_color="white", max_words=1000).generate(all_headlines)
rcParams['figure.figsize'] = 10, 20
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
with open('Text/Build4People.txt') as f:
    lines = f.readlines()
    print(lines)
# Out:
# ['\n', 'During the Build4People Definition Phase we were able to gain a deeper understanding of the \n', 'Cambodian context and local characteristics that concern the research field of the \n', 'Build4People project and the specific research questions according to WP#1. The research \n', 'stays, the comprehensive exchange with our local researc h partners and other stakeholders \n', 'in form of conferences and workshops, as well as many internal project discussions, specified \n', 'our research approach. Furthermore, our interviews (as a preparation for our survey) and the first pre -test of the survey gave manifold insights into the contextual factors, the \n', 'environmental conditions as well as perceptions and experiences of citizens of Phnom Penh. So far, we have observed a rather limited local knowledge on the mindset of the urban \n', 'population from an environmen tal psychology perspective. \n', 'An important insight for us according to the environmental awareness of people 
# ...

# %%
from wordcloud import WordCloud

# image configurations
background_color = "#101010"
height = 720
width = 1080

with open("stopwords.txt", "r") as f:
    stop_words = f.read().split()

# Read a text file and calculate frequency of words in it
with open("Text/Build4People.txt", "r") as f:
    words = f.read().split()

data = dict()

for word in words:
    word = word.lower()
    if word in stop_words:
        continue

    data[word] = data.get(word, 0) + 1

word_cloud = WordCloud(
    background_color=background_color,
    width=width,
    height=height
)

word_cloud.generate_from_frequencies(data)
word_cloud.to_file('image.png')

# %%
stopwords = STOPWORDS
wordcloud = WordCloud(stopwords=stopwords, background_color="white", width=width,height=height, max_words=1000
                     ).generate_from_frequencies(data)
rcParams['figure.figsize'] = 20, 50
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
print(os.path.join("User/Desktop", "file.txt"))
# Out:
# User/Desktop\file.txt
